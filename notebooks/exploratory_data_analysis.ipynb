# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Init: Prepare Packages and Configuration

# %%
# ! pip install libpysal
# ! pip install geopandas libpysal esda matplotlib
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting libpysal
#   Downloading libpysal-4.13.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting esda
#   Downloading esda-2.7.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting numpy>=1.24 (from geopandas)
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.11.0-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging in c:\users\87383\appdata\roaming\python\python311\site-packages (from geopandas) (24.2)
# Collecting pandas>=2.0.0 (from geopandas)
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting beautifulsoup4>=4.10 (from libpysal)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\87383\appdata\roaming\python\python311\site-packages (from libpysal) (4.3.6)
# Collecting requests>=2.27 (from libpysal)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting scipy>=1.8 (from libpysal)
#   Downloading scipy-1.15.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting scikit-learn>=1.1 (from libpysal)
#   Using cached scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.1-cp311-cp311-win_amd64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp311-cp311-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\87383\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.10->libpysal)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\87383\appdata\roaming\python\python311\site-packages (from beautifulsoup4>=4.10->libpysal) (4.12.2)
# Collecting pytz>=2020.1 (from pandas>=2.0.0->geopandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.0.0->geopandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting certifi (from pyogrio>=0.7.2->geopandas)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in c:\users\87383\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.27->libpysal)
#   Using cached charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.27->libpysal)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.27->libpysal)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.1->libpysal)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1->libpysal)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading geopandas-1.1.0-py3-none-any.whl (338 kB)
# Downloading libpysal-4.13.0-py3-none-any.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 18.1 MB/s eta 0:00:00
# Downloading esda-2.7.0-py3-none-any.whl (142 kB)
# Downloading matplotlib-3.10.3-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------- ----------------- 4.5/8.1 MB 20.7 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 18.5 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading contourpy-1.3.2-cp311-cp311-win_amd64.whl (222 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.1-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 18.1 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
# Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# Downloading pillow-11.2.1-cp311-cp311-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 19.3 MB/s eta 0:00:00
# Downloading pyogrio-0.11.0-cp311-cp311-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    -------- ------------------------------- 3.9/19.2 MB 21.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 8.4/19.2 MB 20.8 MB/s eta 0:00:01
#    -------------------------- ------------- 12.8/19.2 MB 21.2 MB/s eta 0:00:01
#    ------------------------------------ --- 17.3/19.2 MB 21.0 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 20.5 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pyproj-3.7.1-cp311-cp311-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ----------------------- ---------------- 3.7/6.3 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 18.3 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.15.3-cp311-cp311-win_amd64.whl (41.2 MB)
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    --- ------------------------------------ 3.9/41.2 MB 19.5 MB/s eta 0:00:02
#    -------- ------------------------------- 8.7/41.2 MB 19.9 MB/s eta 0:00:02
#    ------------ --------------------------- 13.1/41.2 MB 20.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.8/41.2 MB 21.2 MB/s eta 0:00:02
#    --------------------- ------------------ 22.3/41.2 MB 21.0 MB/s eta 0:00:01
#    ------------------------- -------------- 26.7/41.2 MB 21.2 MB/s eta 0:00:01
#    ------------------------------ --------- 31.5/41.2 MB 21.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.2/41.2 MB 21.3 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.2 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------- 41.2/41.2 MB 20.8 MB/s eta 0:00:00
# Downloading shapely-2.1.1-cp311-cp311-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 18.5 MB/s eta 0:00:00
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, urllib3, tzdata, threadpoolctl, soupsieve, pyparsing, pillow, numpy, kiwisolver, joblib, idna, fonttools, cycler, charset-normalizer, certifi, shapely, scipy, requests, pyproj, pyogrio, pandas, contourpy, beautifulsoup4, scikit-learn, matplotlib, geopandas, libpysal, esda
#
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    - --------------------------------------  1/28 [urllib3]
#    - --------------------------------------  1/28 [urllib3]
#    - --------------------------------------  1/28 [urllib3]
#    - --------------------------------------  1/28 [urllib3]
#    - --------------------------------------  1/28 [urllib3]
#    -- -------------------------------------  2/28 [tzdata]
#    -- -------------------------------------  2/28 [tzdata]
#    -- -------------------------------------  2/28 [tzdata]
#    ----- ----------------------------------  4/28 [soupsieve]
#    ------- --------------------------------  5/28 [pyparsing]
#    ------- --------------------------------  5/28 [pyparsing]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    -------- -------------------------------  6/28 [pillow]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ---------- -----------------------------  7/28 [numpy]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    ------------ ---------------------------  9/28 [joblib]
#    -------------- ------------------------- 10/28 [idna]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    --------------- ------------------------ 11/28 [fonttools]
#    ------------------ --------------------- 13/28 [charset-normalizer]
#    ------------------ --------------------- 13/28 [charset-normalizer]
#    ------------------ --------------------- 13/28 [charset-normalizer]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    --------------------- ------------------ 15/28 [shapely]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ---------------------- ----------------- 16/28 [scipy]
#    ------------------------ --------------- 17/28 [requests]
#    ------------------------ --------------- 17/28 [requests]
#    ------------------------- -------------- 18/28 [pyproj]
#    ------------------------- -------------- 18/28 [pyproj]
#    ------------------------- -------------- 18/28 [pyproj]
#    ------------------------- -------------- 18/28 [pyproj]
#    --------------------------- ------------ 19/28 [pyogrio]
#    --------------------------- ------------ 19/28 [pyogrio]
#    --------------------------- ------------ 19/28 [pyogrio]
#    --------------------------- ------------ 19/28 [pyogrio]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ---------------------------- ----------- 20/28 [pandas]
#    ------------------------------ --------- 21/28 [contourpy]
#    ------------------------------ --------- 21/28 [contourpy]
#    ------------------------------ --------- 21/28 [contourpy]
#    ------------------------------- -------- 22/28 [beautifulsoup4]
#    ------------------------------- -------- 22/28 [beautifulsoup4]
#    ------------------------------- -------- 22/28 [beautifulsoup4]
#    ------------------------------- -------- 22/28 [beautifulsoup4]
#    ------------------------------- -------- 22/28 [beautifulsoup4]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    -------------------------------- ------- 23/28 [scikit-learn]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ---------------------------------- ----- 24/28 [matplotlib]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ----------------------------------- ---- 25/28 [geopandas]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    ------------------------------------- -- 26/28 [libpysal]
#    -------------------------------------- - 27/28 [esda]
#    -------------------------------------- - 27/28 [esda]
#    -------------------------------------- - 27/28 [esda]
#    -------------------------------------- - 27/28 [esda]
#    -------------------------------------- - 27/28 [esda]
#    -------------------------------------- - 27/28 [esda]
#    ---------------------------------------- 28/28 [esda]
#
# Successfully installed beautifulsoup4-4.13.4 certifi-2025.4.26 charset-normalizer-3.4.2 contourpy-1.3.2 cycler-0.12.1 esda-2.7.0 fonttools-4.58.1 geopandas-1.1.0 idna-3.10 joblib-1.5.1 kiwisolver-1.4.8 libpysal-4.13.0 matplotlib-3.10.3 numpy-2.2.6 pandas-2.2.3 pillow-11.2.1 pyogrio-0.11.0 pyparsing-3.2.3 pyproj-3.7.1 pytz-2025.2 requests-2.32.3 scikit-learn-1.6.1 scipy-1.15.3 shapely-2.1.1 soupsieve-2.7 threadpoolctl-3.6.0 tzdata-2025.2 urllib3-2.4.0

# %%
pip install notebook ipykernel
python -m ipykernel install --user --name=spatial_env --display-name "Python (spatial_env)"

# %%
# Cancel the comment to install all the packages and libraries needed.
! pip install rasterio matplotlib rasterstats ipynbname imageio tqdm rasterstats
! pip install numpy==1.24.4CURR_PATH

# Configuration
from pathlib import Path
import sys

CURR_PATH = Path().resolve()            # current file path
REPO_PATH = CURR_PATH.parent            # current repository path
DATA_PATH = REPO_PATH / "data"          # path for saving the data
DEMO_PATH = DATA_PATH / "demo-data"     # path for demo purpose 

SRC_PATH = REPO_PATH / "src"    # path for other sources
sys.path.append(str(SRC_PATH))  # add src to system path to import custom functions

# Import customised scripts
from aggregation import*
from missingvalue import*
from visualization import*

# print(REPO_PATH)
# Out:
# Collecting rasterio
#   Using cached rasterio-1.4.3-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Requirement already satisfied: matplotlib in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (3.10.3)
# Collecting rasterstats
#   Downloading rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting ipynbname
#   Downloading ipynbname-2024.1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting imageio
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting affine (from rasterio)
#   Using cached affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs (from rasterio)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from rasterio) (2025.4.26)
# Collecting click>=4.0 (from rasterio)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting cligj>=0.5 (from rasterio)
#   Using cached cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from rasterio) (2.2.6)
# Collecting click-plugins (from rasterio)
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from rasterio) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\87383\appdata\roaming\python\python311\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\87383\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Collecting fiona (from rasterstats)
#   Downloading fiona-1.10.1-cp311-cp311-win_amd64.whl.metadata (58 kB)
# Collecting simplejson (from rasterstats)
#   Downloading simplejson-3.20.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: shapely in d:\projects\msc_group_project\air-pollution-mobility-research-project\.conda\lib\site-packages (from rasterstats) (2.1.1)
# Requirement already satisfied: ipykernel in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipynbname) (6.29.5)
# Requirement already satisfied: colorama in c:\users\87383\appdata\roaming\python\python311\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\87383\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (8.31.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (1.6.0)
# Requirement already satisfied: psutil in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipykernel->ipynbname) (5.14.3)
# Requirement already satisfied: decorator in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\87383\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (4.12.2)
# Requirement already satisfied: wcwidth in c:\users\87383\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->ipynbname) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\87383\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->ipynbname) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\87383\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->ipynbname) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\87383\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->ipynbname) (308)
# Requirement already satisfied: executing>=1.2.0 in c:\users\87383\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->ipynbname) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\87383\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->ipynbname) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\87383\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel->ipynbname) (0.2.3)
# Using cached rasterio-1.4.3-cp311-cp311-win_amd64.whl (25.5 MB)
# Downloading rasterstats-0.20.0-py3-none-any.whl (17 kB)
# Downloading ipynbname-2024.1.0.0-py3-none-any.whl (4.3 kB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading fiona-1.10.1-cp311-cp311-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    --------- ------------------------------ 5.8/24.5 MB 29.3 MB/s eta 0:00:01
#    -------------------- ------------------- 12.8/24.5 MB 31.0 MB/s eta 0:00:01
#    -------------------------------- ------- 20.2/24.5 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 31.0 MB/s eta 0:00:00
# Downloading simplejson-3.20.1-cp311-cp311-win_amd64.whl (75 kB)
# Installing collected packages: tqdm, simplejson, imageio, click, attrs, affine, cligj, click-plugins, rasterio, fiona, rasterstats, ipynbname
#
#    ----------------------------------------  0/12 [tqdm]
#    ----------------------------------------  0/12 [tqdm]
#    ----------------------------------------  0/12 [tqdm]
#    --- ------------------------------------  1/12 [simplejson]
#    --- ------------------------------------  1/12 [simplejson]
#    --- ------------------------------------  1/12 [simplejson]
#    --- ------------------------------------  1/12 [simplejson]
#    ------ ---------------------------------  2/12 [imageio]
#    ------ ---------------------------------  2/12 [imageio]
#    ------ ---------------------------------  2/12 [imageio]
#    ------ ---------------------------------  2/12 [imageio]
#    ------ ---------------------------------  2/12 [imageio]
#    ------ ---------------------------------  2/12 [imageio]
#    ---------- -----------------------------  3/12 [click]
#    ---------- -----------------------------  3/12 [click]
#    ------------- --------------------------  4/12 [attrs]
#    ---------------- -----------------------  5/12 [affine]
#    -------------------------- -------------  8/12 [rasterio]
#    -------------------------- -------------  8/12 [rasterio]
#    -------------------------- -------------  8/12 [rasterio]
#    -------------------------- -------------  8/12 [rasterio]
#    -------------------------- -------------  8/12 [rasterio]
#    -------------------------- -------------  8/12 [rasterio]
#    -------------------------- -------------  8/12 [rasterio]
#    ------------------------------ ---------  9/12 [fiona]
#    ------------------------------ ---------  9/12 [fiona]
#    ------------------------------ ---------  9/12 [fiona]
#    ------------------------------ ---------  9/12 [fiona]
#    ------------------------------ ---------  9/12 [fiona]
#    ------------------------------ ---------  9/12 [fiona]
#    ------------------------------ ---------  9/12 [fiona]
#    ------------------------------------ --- 11/12 [ipynbname]
#    ---------------------------------------- 12/12 [ipynbname]
#
# Successfully installed affine-2.4.0 attrs-25.3.0 click-8.2.1 click-plugins-1.1.1 cligj-0.7.2 fiona-1.10.1 imageio-2.37.0 ipynbname-2024.1.0.0 rasterio-1.4.3 rasterstats-0.20.0 simplejson-3.20.1 tqdm-4.67.1
# ERROR: Invalid requirement: 'numpy==1.24.4CURR_PATH': Expected end or semicolon (after version specifier)
#     numpy==1.24.4CURR_PATH
#          ~~~~~~~~~^

# %% [markdown]
# ## 1 Univariate Data Analysis

# %% [markdown]
# ### 1.1 NO2 Spatial Analysis

# %%
import geopandas as gpd
import pandas as pd
import glob
import matplotlib.pyplot as plt
from libpysal.weights import Queen
from esda.moran import Moran, Moran_Local

# ---------- 参数设置 ----------
addis_gpkg_dir = DATA_PATH / "addis-mesh-data"  # GPKG 文件夹路径
no2_column = "no2_mean"        # no2 列名
simplify_geometry = False # 是否简化 geometry（可选）

# ---------- 步骤 1：合并所有 GPKG ----------
print("正在加载 GPKG 文件...")
files = addis_gpkg_dir.glob("*.gpkg")
gdfs = [gpd.read_file(f) for f in files]
merged_gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40728\2048782422.py in <module>
#       3 import glob
#       4 import matplotlib.pyplot as plt
# ----> 5 from libpysal.weights import Queen
#       6 from esda.moran import Moran, Moran_Local
#       7
#
# d:\Software\Anaconda3_202210\lib\site-packages\libpysal\__init__.py in <module>
#      25 from importlib.metadata import PackageNotFoundError, version
#      26
# ---> 27 from . import cg, examples, io, weights
#      28
#      29 with contextlib.suppress(PackageNotFoundError):
#
# d:\Software\Anaconda3_202210\lib\site-packages\libpysal\cg\__init__.py in <module>
#       9 from .sphere import *
#      10 from .voronoi import *
# ---> 11 from .alpha_shapes import *
#
# d:\Software\Anaconda3_202210\lib\site-packages\libpysal\cg\alpha_shapes.py in <module>
#      14 from scipy import sparse
#      15
# ---> 16 from ..common import requires, jit, HAS_JIT
#      17
#      18 if not HAS_JIT:
#
# d:\Software\Anaconda3_202210\lib\site-packages\libpysal\common.py in <module>
#      29 # import numba.jit OR create mimic decorator and set existence flag
#      30 try:
# ---> 31     from numba import jit
#      32
#      33     HAS_JIT = True
#
# d:\Software\Anaconda3_202210\lib\site-packages\numba\__init__.py in <module>
#      40
#      41 # Re-export vectorize decorators and the thread layer querying function
# ---> 42 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      43                             get_num_threads, set_num_threads)
#      44
#
# d:\Software\Anaconda3_202210\lib\site-packages\numba\np\ufunc\__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize
#       4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One
#       5 from numba.np.ufunc import _internal, array_exprs
#
# d:\Software\Anaconda3_202210\lib\site-packages\numba\np\ufunc\decorators.py in <module>
#       1 import inspect
#       2
# ----> 3 from numba.np.ufunc import _internal
#       4 from numba.np.ufunc.parallel import ParallelUFuncBuilder, ParallelGUFuncBuilder
#       5
#
# SystemError: initialization of _internal failed without raising an exception

# %%
# ---------- 步骤 2：提取 no2 列并去除缺失值 ----------
print("清洗数据...")
no2_gdf = merged_gdf[['geometry', no2_column]].copy()
no2_gdf = no2_gdf.dropna(subset=[no2_column])
no2_gdf = no2_gdf.reset_index(drop=True)

# 可选：简化 geometry（加速邻接构建）
if simplify_geometry:
    no2_gdf['geometry'] = no2_gdf['geometry'].simplify(0.001)

# ---------- 步骤 3：构建 Queen 邻接矩阵 ----------
print("构建空间邻接矩阵（Queen 邻接）...")
w = Queen.from_dataframe(no2_gdf)
w.transform = 'r'  # row-standardized weights

# ---------- 步骤 4：计算全局 Moran’s I ----------
print("计算 Moran's I...")
moran = Moran(no2_gdf[no2_column], w)
print(f"Moran’s I: {moran.I:.4f}")
print(f"p-value (normal approximation): {moran.p_norm:.4f}")

# ---------- 步骤 5：计算局部 Moran’s I (LISA) ----------
print("计算局部自相关 (Moran_Local)...")
moran_local = Moran_Local(no2_gdf[no2_column], w)
no2_gdf['Is_Hotspot'] = moran_local.Is
no2_gdf['Local_I'] = moran_local.Is * moran_local.q  # 四象限编码（1=HH, 2=LH, 3=LL, 4=HL）

# ---------- 步骤 6：可视化 Hotspot Map ----------
print("绘制热点图...")
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
no2_gdf.plot(column='Local_I', cmap='coolwarm', legend=True, ax=ax)
ax.set_title("局部空间自相关 (LISA): no2", fontsize=14)
ax.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 NO2 Temporal Analysis

# %% [markdown]
# ## 2 Multivariate Data Analysis

# %% [markdown]
# ### 2.1 Correlation Matrix
