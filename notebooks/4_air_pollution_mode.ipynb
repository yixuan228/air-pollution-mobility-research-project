# %% [markdown]
# # NO2 Models

# %% [markdown]
# ## Init: Prepare Packages and Configuration

# %%
# Cancel the comment to install all the packages and libraries needed.
# ! pip install rasterio matplotlib rasterstats ipynbname imageio tqdm rasterstats
# ! pip install numpy==1.24.4CURR_PATH
# ! pip install libpysal
# ! pip install geopandas libpysal esda matplotlib
# ! pip install seaborn

# Configuration
from pathlib import Path
import sys

CURR_PATH = Path().resolve()            # current file path
REPO_PATH = CURR_PATH.parent            # current repository path
DATA_PATH = REPO_PATH / "data"          # path for saving the data
DEMO_PATH = DATA_PATH / "demo-data"     # path for demo purpose 

SRC_PATH = REPO_PATH / "src"    # path for other sources
sys.path.append(str(SRC_PATH))  # add src to system path to import custom functions

# print(REPO_PATH)

# %%
import geopandas as gpd
import pandas as pd
from tqdm import tqdm
from datetime import timedelta, datetime
import os

# 假设文件按日期排序，文件名可解析为日期
mesh_folder = DATA_PATH / 'addis-mesh-data'
file_paths = sorted(mesh_folder.glob("*.gpkg"))  # 你的 730 个 GPKG 文件路径

all_data = []

for i, path in tqdm(enumerate(file_paths), total=len(file_paths)):
    date = datetime(2023, 1, 1) + timedelta(days=i)  # 修改起始日期为真实值
    gdf = gpd.read_file(path)
    gdf["date"] = date
    all_data.append(gdf)

full_df = pd.concat(all_data, ignore_index=True)
# Out:
# 100%|██████████| 731/731 [00:12<00:00, 57.19it/s]
# C:\Users\87383\AppData\Local\Temp\ipykernel_30340\1835601351.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat(all_data, ignore_index=True)

# %%
## Yesterday NO2
full_df.sort_values(["geom_id", "date"], inplace=True)
full_df["no2_yesterday"] = full_df.groupby("geom_id")["no2_mean"].shift(1)

# %%
import warnings
from libpysal.weights import KNN

# 假设 sample_gdf 是某一天的网格
sample_gdf = full_df[full_df['date'] == full_df['date'].min()].reset_index(drop=True)

# 设置 K（邻居个数）
k_neighbors = 8  # 通常选择8邻域

# 构建 KNN 空间权重
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    w = KNN.from_dataframe(sample_gdf, k=k_neighbors)

# row-standardized weights（可选）
w.transform = 'r'

# 构建 geom_id -> 邻居 geom_id 的映射字典
geom_id_to_neighbors = {}

# sample_gdf 的索引 i <=> geom_id 的映射
index_to_geom_id = dict(sample_gdf['geom_id'].items())

for i, neighbors in w.neighbors.items():
    geom_id = index_to_geom_id[i]
    neighbor_ids = [index_to_geom_id[j] for j in neighbors]
    geom_id_to_neighbors[geom_id] = neighbor_ids

# %%
geom_id_to_neighbors
# Out:
# {0: [5, 1, 6, 14, 2, 15, 13, 7],
#  1: [6, 0, 2, 5, 7, 15, 3, 14],
#  2: [3, 7, 1, 8, 6, 4, 16, 0],
#  3: [2, 8, 4, 7, 9, 17, 1, 16],
#  4: [9, 3, 8, 2, 18, 7, 17, 16],
#  5: [0, 6, 14, 1, 15, 13, 23, 7],
#  6: [1, 15, 5, 7, 0, 14, 2, 16],
#  7: [8, 2, 16, 6, 3, 17, 1, 15],
#  8: [7, 3, 9, 17, 2, 16, 4, 18],
#  9: [4, 18, 8, 3, 17, 7, 27, 2],
#  10: [19, 11, 20, 28, 12, 29, 21, 30],
#  11: [20, 10, 12, 19, 21, 13, 29, 22],
#  12: [13, 21, 11, 22, 20, 14, 30, 10],
#  13: [12, 22, 14, 21, 23, 5, 11, 31],
#  14: [23, 13, 5, 15, 22, 24, 6, 12],
#  15: [24, 14, 6, 16, 23, 5, 25, 7],
#  16: [17, 25, 7, 15, 26, 8, 24, 6],
#  17: [16, 26, 18, 8, 25, 7, 27, 9],
#  18: [27, 9, 17, 26, 8, 16, 36, 4],
#  19: [10, 28, 20, 29, 11, 38, 21, 39],
#  20: [11, 29, 19, 21, 28, 10, 30, 12],
#  21: [22, 30, 12, 20, 13, 31, 29, 11],
#  22: [21, 13, 31, 23, 30, 12, 32, 14],
#  23: [32, 14, 24, 22, 13, 33, 31, 15],
#  24: [15, 33, 23, 25, 32, 14, 16, 34],
#  25: [26, 16, 34, 24, 17, 35, 33, 15],
#  26: [25, 35, 17, 27, 34, 16, 36, 18],
#  27: [18, 36, 26, 35, 17, 25, 46, 9],
#  28: [19, 38, 29, 20, 39, 10, 52, 30],
#  29: [20, 28, 39, 30, 19, 38, 21, 40],
#  30: [31, 21, 40, 29, 22, 41, 20, 39],
#  31: [30, 22, 41, 32, 21, 40, 23, 42],
#  32: [23, 31, 42, 33, 22, 24, 43, 41],
#  33: [24, 43, 32, 34, 23, 42, 25, 44],
#  34: [35, 25, 44, 33, 26, 45, 24, 43],
#  35: [34, 26, 36, 45, 25, 44, 27, 46],
#  36: [27, 46, 35, 47, 26, 45, 34, 18],
#  37: [51, 50, 65, 66, 64, 49, 63, 82],
#  38: [52, 28, 39, 53, 29, 69, 19, 40],
#  39: [53, 29, 38, 40, 52, 28, 54, 30],
#  40: [41, 54, 30, 39, 55, 31, 53, 29],
#  41: [40, 55, 31, 42, 54, 30, 56, 32],
#  42: [56, 32, 41, 43, 55, 57, 33, 31],
#  43: [57, 33, 42, 44, 56, 32, 58, 34],
#  44: [45, 58, 34, 43, 59, 35, 57, 33],
#  45: [44, 59, 35, 46, 58, 34, 60, 36],
#  46: [47, 60, 36, 45, 61, 59, 35, 44],
#  47: [46, 61, 48, 60, 36, 62, 45, 78],
#  48: [62, 47, 49, 61, 63, 50, 46, 79],
#  49: [50, 63, 48, 64, 62, 80, 47, 51],
#  50: [49, 64, 51, 63, 65, 37, 48, 81],
#  51: [65, 37, 50, 66, 64, 82, 49, 81],
#  52: [69, 38, 53, 39, 70, 68, 85, 28],
#  53: [39, 70, 52, 54, 69, 38, 71, 40],
#  54: [55, 71, 40, 53, 41, 72, 70, 39],
#  55: [54, 72, 41, 56, 71, 40, 73, 42],
#  56: [42, 73, 55, 57, 41, 74, 43, 72],
#  57: [43, 74, 56, 58, 73, 42, 44, 75],
#  58: [59, 75, 44, 57, 45, 76, 43, 74],
#  59: [58, 45, 76, 60, 75, 44, 77, 46],
#  60: [61, 46, 77, 59, 78, 47, 76, 45],
#  61: [60, 47, 78, 62, 46, 77, 48, 79],
#  62: [48, 79, 61, 63, 47, 80, 78, 49],
#  63: [64, 80, 49, 62, 50, 81, 79, 48],
#  542: [527, 541, 543, 526, 545, 528, 544, 506],
#  543: [544, 545, 528, 542, 529, 527, 507, 541],
#  544: [543, 529, 545, 528, 530, 542, 508, 507],
#  545: [543, 544, 542, 528, 529, 527, 541, 530]}

# %%
# full_df

# %%
def compute_neighbor_no2(row, df_dict):
    date = row["date"]
    geom_id = row["geom_id"]
    prev_date = date - timedelta(days=1)
    if prev_date not in df_dict:
        return None
    prev_day_df = df_dict[prev_date]
    neighbors = geom_id_to_neighbors.get(geom_id, [])
    values = prev_day_df[prev_day_df["geom_id"].isin(neighbors)]["no2_mean"]
    return values.mean() if not values.empty else None

# 按天切分数据用于快速访问
df_by_date = {d: gdf for d, gdf in full_df.groupby("date")}
full_df["no2_neighbor_yesterday"] = full_df.apply(lambda row: compute_neighbor_no2(row, df_by_date), axis=1)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

clean_df = full_df.dropna(subset=["no2_mean", "no2_yesterday", "no2_neighbor_yesterday"])

features = ["no2_yesterday", "no2_neighbor_yesterday"] + [col for col in full_df.columns if col not in ["no2_mean", "geometry", "date", "geom_id"]]

X = clean_df[features].values
y = clean_df["no2_mean"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "max_depth": 6,
    "eta": 0.1
}

evals = [(dtrain, "train"), (dtest, "eval")]

num_round = 100

# 训练并打印日志
bst = xgb.train(params, dtrain, num_round, evals, verbose_eval=True)

# 预测
y_pred = bst.predict(dtest)

print("Final RMSE:", mean_squared_error(y_test, y_pred, squared=False))

# 取训练日志，用于画图
evals_result = {}

bst = xgb.train(
    params, 
    dtrain, 
    num_round, 
    evals, 
    evals_result=evals_result,  # 自动保存训练过程中的指标
    verbose_eval=True
)

# 预测
y_pred = bst.predict(dtest)
print("Final RMSE:", mean_squared_error(y_test, y_pred, squared=False))

# 画图
train_rmse = evals_result['train']['rmse']
eval_rmse = evals_result['eval']['rmse']

plt.plot(train_rmse, label='Train RMSE')
plt.plot(eval_rmse, label='Eval RMSE')
plt.xlabel('Round')
plt.ylabel('RMSE')
plt.title('XGBoost Training Progress')
plt.legend()
plt.show()
# Out:
# [0]	train-rmse:0.00002	eval-rmse:0.00002
# [1]	train-rmse:0.00002	eval-rmse:0.00002
# d:\Software\Anaconda3\envs\gdp_env\Lib\site-packages\xgboost\core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [2]	train-rmse:0.00002	eval-rmse:0.00002
# [3]	train-rmse:0.00002	eval-rmse:0.00002
# [4]	train-rmse:0.00002	eval-rmse:0.00002
# [5]	train-rmse:0.00002	eval-rmse:0.00002
# [6]	train-rmse:0.00002	eval-rmse:0.00002
# [7]	train-rmse:0.00002	eval-rmse:0.00002
# [8]	train-rmse:0.00002	eval-rmse:0.00002
# [9]	train-rmse:0.00002	eval-rmse:0.00002
# [10]	train-rmse:0.00002	eval-rmse:0.00002
# [11]	train-rmse:0.00002	eval-rmse:0.00002
# [12]	train-rmse:0.00002	eval-rmse:0.00002
# [13]	train-rmse:0.00002	eval-rmse:0.00002
# [14]	train-rmse:0.00002	eval-rmse:0.00002
# [15]	train-rmse:0.00002	eval-rmse:0.00002
# [16]	train-rmse:0.00002	eval-rmse:0.00002
# [80]	train-rmse:0.00002	eval-rmse:0.00002
# [81]	train-rmse:0.00002	eval-rmse:0.00002
# [82]	train-rmse:0.00002	eval-rmse:0.00002
# [83]	train-rmse:0.00002	eval-rmse:0.00002
# [84]	train-rmse:0.00002	eval-rmse:0.00002
# [85]	train-rmse:0.00002	eval-rmse:0.00002
# [86]	train-rmse:0.00002	eval-rmse:0.00002
# [87]	train-rmse:0.00002	eval-rmse:0.00002
# [88]	train-rmse:0.00002	eval-rmse:0.00002
# [89]	train-rmse:0.00002	eval-rmse:0.00002
# [90]	train-rmse:0.00002	eval-rmse:0.00002
# [91]	train-rmse:0.00002	eval-rmse:0.00002
# [92]	train-rmse:0.00002	eval-rmse:0.00002
# [93]	train-rmse:0.00002	eval-rmse:0.00002
# [94]	train-rmse:0.00002	eval-rmse:0.00002
# [95]	train-rmse:0.00002	eval-rmse:0.00002
# [96]	train-rmse:0.00002	eval-rmse:0.00002
# [97]	train-rmse:0.00002	eval-rmse:0.00002
# [98]	train-rmse:0.00002	eval-rmse:0.00002
# [99]	train-rmse:0.00002	eval-rmse:0.00002
# Final RMSE: 1.9019589427912927e-05

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# 数据清理，去除关键列缺失值
clean_df = full_df.dropna(subset=["no2_mean", "no2_yesterday", "no2_neighbor_yesterday"])

# 特征列：辅助变量 + 其他所有除目标和非数值列
features = ["no2_yesterday", "no2_neighbor_yesterday"] + [
    col for col in full_df.columns
    if col not in ["no2_mean", "geometry", "date", "geom_id", "no2_yesterday", "no2_neighbor_yesterday"]
]

X = clean_df[features].values
y = clean_df["no2_mean"].values

# 划分训练测试集（按时间顺序，不打乱）
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 创建 DMatrix，传入真实特征名
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dtest = xgb.DMatrix(X_test, label=y_test, feature_names=features)

params = {
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "max_depth": 6,
    "eta": 0.1
}

evals = [(dtrain, "train"), (dtest, "eval")]
num_round = 100

# 训练模型并保存评估指标
evals_result = {}
bst = xgb.train(
    params, dtrain, num_round, evals,
    evals_result=evals_result,
    verbose_eval=True
)

# 预测并计算RMSE
y_pred = bst.predict(dtest)
print("Final RMSE:", mean_squared_error(y_test, y_pred, squared=False))

# 绘制训练过程中的RMSE曲线
plt.plot(evals_result['train']['rmse'], label='Train RMSE')
plt.plot(evals_result['eval']['rmse'], label='Eval RMSE')
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('XGBoost Training Progress')
plt.legend()
plt.show()

# 获取特征重要性，importance_type可选 'weight', 'gain', 'cover'
importance_dict = bst.get_score(importance_type='weight')

# 按重要性排序，准备打印和绘图
importances = [(feat, importance_dict.get(feat, 0)) for feat in features]
importances.sort(key=lambda x: x[1], reverse=True)

print("Feature Importances:")
for feat, score in importances:
    print(f"{feat}: {score}")

# 绘制特征重要性柱状图
feature_names = [i[0] for i in importances]
scores = [i[1] for i in importances]

plt.figure(figsize=(10, 6))
plt.barh(feature_names[::-1], scores[::-1])  # 反转排序，重要性高的在上面
plt.xlabel("Feature Importance (weight)")
plt.title("XGBoost Feature Importance")
plt.tight_layout()
plt.show()
# Out:
# [0]	train-rmse:0.00002	eval-rmse:0.00002
# [1]	train-rmse:0.00002	eval-rmse:0.00002
# d:\Software\Anaconda3\envs\gdp_env\Lib\site-packages\xgboost\core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
#
# [55]	train-rmse:0.00002	eval-rmse:0.00002
# [56]	train-rmse:0.00002	eval-rmse:0.00002
# [57]	train-rmse:0.00002	eval-rmse:0.00002
# [58]	train-rmse:0.00002	eval-rmse:0.00002
# [59]	train-rmse:0.00002	eval-rmse:0.00002
# [60]	train-rmse:0.00002	eval-rmse:0.00002
# [61]	train-rmse:0.00002	eval-rmse:0.00002
# [62]	train-rmse:0.00002	eval-rmse:0.00002
# [63]	train-rmse:0.00002	eval-rmse:0.00002
# [64]	train-rmse:0.00002	eval-rmse:0.00002
# [65]	train-rmse:0.00002	eval-rmse:0.00002
# [66]	train-rmse:0.00002	eval-rmse:0.00002
# [67]	train-rmse:0.00002	eval-rmse:0.00002
# [68]	train-rmse:0.00002	eval-rmse:0.00002
# [69]	train-rmse:0.00002	eval-rmse:0.00002
# [70]	train-rmse:0.00002	eval-rmse:0.00002
# [71]	train-rmse:0.00002	eval-rmse:0.00002
# [72]	train-rmse:0.00002	eval-rmse:0.00002
# [73]	train-rmse:0.00002	eval-rmse:0.00002
# [74]	train-rmse:0.00002	eval-rmse:0.00002
# [75]	train-rmse:0.00002	eval-rmse:0.00002
# [76]	train-rmse:0.00002	eval-rmse:0.00002
# [77]	train-rmse:0.00002	eval-rmse:0.00002
# [78]	train-rmse:0.00002	eval-rmse:0.00002
# [79]	train-rmse:0.00002	eval-rmse:0.00002
# [80]	train-rmse:0.00002	eval-rmse:0.00002
# [81]	train-rmse:0.00002	eval-rmse:0.00002
# [82]	train-rmse:0.00002	eval-rmse:0.00002
# [83]	train-rmse:0.00002	eval-rmse:0.00002
# [84]	train-rmse:0.00002	eval-rmse:0.00002
# [85]	train-rmse:0.00002	eval-rmse:0.00002
# [86]	train-rmse:0.00002	eval-rmse:0.00002
# [87]	train-rmse:0.00002	eval-rmse:0.00002
# [88]	train-rmse:0.00002	eval-rmse:0.00002
# [89]	train-rmse:0.00002	eval-rmse:0.00002
# [90]	train-rmse:0.00002	eval-rmse:0.00002
# [91]	train-rmse:0.00002	eval-rmse:0.00002
# [92]	train-rmse:0.00002	eval-rmse:0.00002
# [93]	train-rmse:0.00002	eval-rmse:0.00002
# [94]	train-rmse:0.00002	eval-rmse:0.00002
# [95]	train-rmse:0.00002	eval-rmse:0.00002
# [96]	train-rmse:0.00002	eval-rmse:0.00002
# [97]	train-rmse:0.00002	eval-rmse:0.00002
# [98]	train-rmse:0.00002	eval-rmse:0.00002
# [99]	train-rmse:0.00002	eval-rmse:0.00002
# Final RMSE: 1.9019589427912927e-05
# Feature Importances:
# no2_neighbor_yesterday: 27.0
# NTL_mean: 10.0
# pop_sum_m: 6.0
# no2_yesterday: 3.0
# road_len: 0
# road_share: 0
# poi_count: 0
# poi_share: 0
# lu_industrial_area: 0
# lu_industrial_share: 0
# lu_commercial_area: 0
# lu_commercial_share: 0
# lu_residential_area: 0
# lu_residential_share: 0
# lu_retail_area: 0
# lu_retail_share: 0
# lu_farmland_area: 0
# lu_farmland_share: 0
# lu_farmyard_area: 0
# lu_farmyard_share: 0
# road_motorway_len: 0
# road_trunk_len: 0
# road_primary_len: 0
# road_secondary_len: 0
# road_tertiary_len: 0
# road_residential_len: 0
# fossil_pp_count: 0

# %% [markdown]
# Normalize both No2 and other feature

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np

# 去除缺失值
clean_df = full_df.dropna(subset=["no2_mean", "no2_yesterday", "no2_neighbor_yesterday"])

# 选特征
features = ["no2_yesterday", "no2_neighbor_yesterday"] + [
    col for col in full_df.columns
    if col not in ["no2_mean", "geometry", "date", "geom_id", "no2_yesterday", "no2_neighbor_yesterday"]
]

X = clean_df[features].values
y = clean_df["no2_mean"].values.reshape(-1, 1)  # 目标需要2D给scaler

# 划分训练测试集（不打乱）
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 归一化
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# 只用训练数据fit，避免数据泄漏
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train).ravel()  # ravel转成1D，xgboost需要
y_test_scaled = scaler_y.transform(y_test).ravel()

# 创建 DMatrix，带特征名
dtrain = xgb.DMatrix(X_train_scaled, label=y_train_scaled, feature_names=features)
dtest = xgb.DMatrix(X_test_scaled, label=y_test_scaled, feature_names=features)

params = {
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "max_depth": 6,
    "eta": 0.1
}

evals = [(dtrain, "train"), (dtest, "eval")]
num_round = 100

evals_result = {}

bst = xgb.train(
    params, dtrain, num_round, evals,
    evals_result=evals_result,
    verbose_eval=True
)

# 预测，得到的是归一化后的预测值
y_pred_scaled = bst.predict(dtest)

# 反归一化回原始尺度
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()

print("Final RMSE (original scale):", mean_squared_error(y_test.ravel(), y_pred, squared=False))

# 画训练过程RMSE曲线（归一化指标）
plt.plot(evals_result['train']['rmse'], label='Train RMSE')
plt.plot(evals_result['eval']['rmse'], label='Eval RMSE')
plt.xlabel('Iteration')
plt.ylabel('RMSE (scaled)')
plt.title('XGBoost Training Progress')
plt.legend()
plt.show()

# 输出特征重要性
importance_dict = bst.get_score(importance_type='weight')
importances = [(feat, importance_dict.get(feat, 0)) for feat in features]
importances.sort(key=lambda x: x[1], reverse=True)

print("Feature Importances:")
for feat, score in importances:
    print(f"{feat}: {score}")

plt.figure(figsize=(10, 6))
plt.barh([i[0] for i in importances][::-1], [i[1] for i in importances][::-1])
plt.xlabel("Feature Importance (weight)")
plt.title("XGBoost Feature Importance")
plt.tight_layout()
plt.show()
# Out:
# [0]	train-rmse:0.06604	eval-rmse:0.07069
# [1]	train-rmse:0.06475	eval-rmse:0.06966
# d:\Software\Anaconda3\envs\gdp_env\Lib\site-packages\xgboost\core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [2]	train-rmse:0.06367	eval-rmse:0.06882
# [3]	train-rmse:0.06279	eval-rmse:0.06813
# [4]	train-rmse:0.06204	eval-rmse:0.06758
# [5]	train-rmse:0.06143	eval-rmse:0.06714
# [6]	train-rmse:0.06091	eval-rmse:0.06679
# [7]	train-rmse:0.06048	eval-rmse:0.06651
# [8]	train-rmse:0.06013	eval-rmse:0.06626
# [9]	train-rmse:0.05983	eval-rmse:0.06607
# [10]	train-rmse:0.05958	eval-rmse:0.06591
# [11]	train-rmse:0.05937	eval-rmse:0.06579
# [12]	train-rmse:0.05919	eval-rmse:0.06570
# [13]	train-rmse:0.05904	eval-rmse:0.06563
# [14]	train-rmse:0.05891	eval-rmse:0.06556
# [15]	train-rmse:0.05880	eval-rmse:0.06551
# [16]	train-rmse:0.05870	eval-rmse:0.06547
# [17]	train-rmse:0.05861	eval-rmse:0.06544
# [18]	train-rmse:0.05853	eval-rmse:0.06539
# [19]	train-rmse:0.05846	eval-rmse:0.06537
# [20]	train-rmse:0.05840	eval-rmse:0.06536
# [21]	train-rmse:0.05834	eval-rmse:0.06532
# [22]	train-rmse:0.05829	eval-rmse:0.06532
# [23]	train-rmse:0.05824	eval-rmse:0.06532
# [24]	train-rmse:0.05820	eval-rmse:0.06532
# [25]	train-rmse:0.05815	eval-rmse:0.06531
# [26]	train-rmse:0.05811	eval-rmse:0.06532
# [27]	train-rmse:0.05807	eval-rmse:0.06534
# [28]	train-rmse:0.05803	eval-rmse:0.06534
# [29]	train-rmse:0.05800	eval-rmse:0.06534
# [30]	train-rmse:0.05797	eval-rmse:0.06536
# [31]	train-rmse:0.05792	eval-rmse:0.06535
# [32]	train-rmse:0.05790	eval-rmse:0.06536
# [33]	train-rmse:0.05787	eval-rmse:0.06537
# [34]	train-rmse:0.05783	eval-rmse:0.06538
# [35]	train-rmse:0.05780	eval-rmse:0.06538
# [36]	train-rmse:0.05777	eval-rmse:0.06538
# [37]	train-rmse:0.05775	eval-rmse:0.06539
# [38]	train-rmse:0.05772	eval-rmse:0.06540
# [39]	train-rmse:0.05770	eval-rmse:0.06541
# [40]	train-rmse:0.05767	eval-rmse:0.06540
# [41]	train-rmse:0.05765	eval-rmse:0.06541
# [42]	train-rmse:0.05764	eval-rmse:0.06541
# [43]	train-rmse:0.05761	eval-rmse:0.06542
# [44]	train-rmse:0.05760	eval-rmse:0.06543
# [45]	train-rmse:0.05756	eval-rmse:0.06543
# [46]	train-rmse:0.05755	eval-rmse:0.06544
# [47]	train-rmse:0.05754	eval-rmse:0.06544
# [48]	train-rmse:0.05751	eval-rmse:0.06545
# [49]	train-rmse:0.05750	eval-rmse:0.06546
# [50]	train-rmse:0.05748	eval-rmse:0.06547
# [51]	train-rmse:0.05747	eval-rmse:0.06546
# [52]	train-rmse:0.05746	eval-rmse:0.06546
# [53]	train-rmse:0.05745	eval-rmse:0.06547
# [54]	train-rmse:0.05743	eval-rmse:0.06547
# [55]	train-rmse:0.05742	eval-rmse:0.06547
# [56]	train-rmse:0.05741	eval-rmse:0.06549
# [57]	train-rmse:0.05740	eval-rmse:0.06548
# [58]	train-rmse:0.05739	eval-rmse:0.06548
# [59]	train-rmse:0.05737	eval-rmse:0.06547
# [60]	train-rmse:0.05736	eval-rmse:0.06548
# [61]	train-rmse:0.05734	eval-rmse:0.06548
# [62]	train-rmse:0.05734	eval-rmse:0.06549
# [63]	train-rmse:0.05733	eval-rmse:0.06549
# [64]	train-rmse:0.05731	eval-rmse:0.06549
# [65]	train-rmse:0.05730	eval-rmse:0.06549
# [66]	train-rmse:0.05728	eval-rmse:0.06550
# [67]	train-rmse:0.05727	eval-rmse:0.06551
# [68]	train-rmse:0.05726	eval-rmse:0.06551
# [69]	train-rmse:0.05725	eval-rmse:0.06551
# [70]	train-rmse:0.05724	eval-rmse:0.06551
# [71]	train-rmse:0.05723	eval-rmse:0.06550
# [72]	train-rmse:0.05721	eval-rmse:0.06550
# [73]	train-rmse:0.05720	eval-rmse:0.06550
# [74]	train-rmse:0.05719	eval-rmse:0.06550
# [75]	train-rmse:0.05718	eval-rmse:0.06550
# [76]	train-rmse:0.05716	eval-rmse:0.06550
# [77]	train-rmse:0.05715	eval-rmse:0.06550
# [78]	train-rmse:0.05714	eval-rmse:0.06551
# [79]	train-rmse:0.05712	eval-rmse:0.06550
# [80]	train-rmse:0.05711	eval-rmse:0.06552
# [81]	train-rmse:0.05709	eval-rmse:0.06552
# [82]	train-rmse:0.05708	eval-rmse:0.06553
# [83]	train-rmse:0.05707	eval-rmse:0.06553
# [84]	train-rmse:0.05706	eval-rmse:0.06553
# [85]	train-rmse:0.05705	eval-rmse:0.06553
# [86]	train-rmse:0.05703	eval-rmse:0.06553
# [87]	train-rmse:0.05702	eval-rmse:0.06552
# [88]	train-rmse:0.05702	eval-rmse:0.06553
# [89]	train-rmse:0.05701	eval-rmse:0.06553
# [90]	train-rmse:0.05700	eval-rmse:0.06554
# [91]	train-rmse:0.05700	eval-rmse:0.06554
# [92]	train-rmse:0.05699	eval-rmse:0.06555
# [93]	train-rmse:0.05697	eval-rmse:0.06555
# [94]	train-rmse:0.05696	eval-rmse:0.06554
# [95]	train-rmse:0.05695	eval-rmse:0.06554
# [96]	train-rmse:0.05692	eval-rmse:0.06554
# [97]	train-rmse:0.05689	eval-rmse:0.06553
# [98]	train-rmse:0.05689	eval-rmse:0.06555
# [99]	train-rmse:0.05687	eval-rmse:0.06555
# Final RMSE (original scale): 1.8993189131233392e-05
# Feature Importances:
# NTL_mean: 1605.0
# no2_yesterday: 1408.0
# no2_neighbor_yesterday: 990.0
# pop_sum_m: 477.0
# lu_residential_area: 268.0
# road_primary_len: 240.0
# road_residential_len: 232.0
# road_len: 222.0
# road_tertiary_len: 137.0
# road_secondary_len: 135.0
# lu_industrial_area: 91.0
# lu_farmland_area: 66.0
# road_trunk_len: 55.0
# lu_commercial_area: 47.0
# lu_farmyard_area: 42.0
# lu_retail_area: 36.0
# poi_count: 27.0
# road_share: 0
# poi_share: 0
# lu_industrial_share: 0
# lu_commercial_share: 0
# lu_residential_share: 0
# lu_retail_share: 0
# lu_farmland_share: 0
# lu_farmyard_share: 0
# road_motorway_len: 0
# fossil_pp_count: 0

# %% [markdown]
# Only scale the features

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np

# 去除缺失值
clean_df = full_df.dropna(subset=["no2_mean", "no2_yesterday", "no2_neighbor_yesterday"])

# 选特征
features = ["no2_yesterday", "no2_neighbor_yesterday"] + [
    col for col in full_df.columns
    if col not in ["no2_mean", "geometry", "date", "geom_id", "no2_yesterday", "no2_neighbor_yesterday"]
]

X = clean_df[features].values
y = clean_df["no2_mean"].values.reshape(-1, 1)  # 目标需要2D给scaler

# 划分训练测试集（不打乱）
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 归一化
scaler_X = MinMaxScaler()
# scaler_y = MinMaxScaler()

# 只用训练数据fit，避免数据泄漏
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# y_train_scaled = scaler_y.fit_transform(y_train).ravel()  # ravel转成1D，xgboost需要
# y_test_scaled = scaler_y.transform(y_test).ravel()

# 创建 DMatrix，带特征名
dtrain = xgb.DMatrix(X_train_scaled, label=y_train, feature_names=features)
dtest = xgb.DMatrix(X_test_scaled, label=y_test, feature_names=features)

params = {
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "max_depth": 6,
    "eta": 0.1
}

evals = [(dtrain, "train"), (dtest, "eval")]
num_round = 100

evals_result = {}

bst = xgb.train(
    params, dtrain, num_round, evals,
    evals_result=evals_result,
    verbose_eval=True
)

# 预测，得到的是归一化后的预测值
y_pred = bst.predict(dtest)

# 反归一化回原始尺度
# y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()

print("Final RMSE (original scale):", mean_squared_error(y_test.ravel(), y_pred, squared=False))

# 画训练过程RMSE曲线（归一化指标）
plt.plot(evals_result['train']['rmse'], label='Train RMSE')
plt.plot(evals_result['eval']['rmse'], label='Eval RMSE')
plt.xlabel('Iteration')
plt.ylabel('RMSE (scaled)')
plt.title('XGBoost Training Progress')
plt.legend()
plt.show()
# Out:
# [0]	train-rmse:0.00002	eval-rmse:0.00002
# [1]	train-rmse:0.00002	eval-rmse:0.00002
# d:\Software\Anaconda3\envs\gdp_env\Lib\site-packages\xgboost\core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [2]	train-rmse:0.00002	eval-rmse:0.00002
# [3]	train-rmse:0.00002	eval-rmse:0.00002
# [4]	train-rmse:0.00002	eval-rmse:0.00002
# [5]	train-rmse:0.00002	eval-rmse:0.00002
# [6]	train-rmse:0.00002	eval-rmse:0.00002
# [7]	train-rmse:0.00002	eval-rmse:0.00002
# [8]	train-rmse:0.00002	eval-rmse:0.00002
# [9]	train-rmse:0.00002	eval-rmse:0.00002
# [10]	train-rmse:0.00002	eval-rmse:0.00002
# [11]	train-rmse:0.00002	eval-rmse:0.00002
# [12]	train-rmse:0.00002	eval-rmse:0.00002
# [13]	train-rmse:0.00002	eval-rmse:0.00002
# [14]	train-rmse:0.00002	eval-rmse:0.00002
# [15]	train-rmse:0.00002	eval-rmse:0.00002
# [16]	train-rmse:0.00002	eval-rmse:0.00002
# [17]	train-rmse:0.00002	eval-rmse:0.00002
# [18]	train-rmse:0.00002	eval-rmse:0.00002
# [19]	train-rmse:0.00002	eval-rmse:0.00002
# [20]	train-rmse:0.00002	eval-rmse:0.00002
# [21]	train-rmse:0.00002	eval-rmse:0.00002
# [22]	train-rmse:0.00002	eval-rmse:0.00002
# [23]	train-rmse:0.00002	eval-rmse:0.00002
# [24]	train-rmse:0.00002	eval-rmse:0.00002
# [25]	train-rmse:0.00002	eval-rmse:0.00002
# [26]	train-rmse:0.00002	eval-rmse:0.00002
# [27]	train-rmse:0.00002	eval-rmse:0.00002
# [28]	train-rmse:0.00002	eval-rmse:0.00002
# [29]	train-rmse:0.00002	eval-rmse:0.00002
# [30]	train-rmse:0.00002	eval-rmse:0.00002
# [31]	train-rmse:0.00002	eval-rmse:0.00002
# [32]	train-rmse:0.00002	eval-rmse:0.00002
# [33]	train-rmse:0.00002	eval-rmse:0.00002
# [89]	train-rmse:0.00002	eval-rmse:0.00002
# [90]	train-rmse:0.00002	eval-rmse:0.00002
# [91]	train-rmse:0.00002	eval-rmse:0.00002
# [92]	train-rmse:0.00002	eval-rmse:0.00002
# [93]	train-rmse:0.00002	eval-rmse:0.00002
# [94]	train-rmse:0.00002	eval-rmse:0.00002
# [95]	train-rmse:0.00002	eval-rmse:0.00002
# [96]	train-rmse:0.00002	eval-rmse:0.00002
# [97]	train-rmse:0.00002	eval-rmse:0.00002
# [98]	train-rmse:0.00002	eval-rmse:0.00002
# [99]	train-rmse:0.00002	eval-rmse:0.00002
# Final RMSE (original scale): 1.9017652080554403e-05

# %%
# 输出特征重要性
importance_dict = bst.get_score(importance_type='weight')  # weight
importances = [(feat, importance_dict.get(feat, 0)) for feat in features]
importances.sort(key=lambda x: x[1], reverse=True)

print("Feature Importances:")
for feat, score in importances:
    print(f"{feat}: {score}")

plt.figure(figsize=(10, 6))
plt.barh([i[0] for i in importances][::-1], [i[1] for i in importances][::-1])
plt.xlabel("Feature Importance (weight)")
plt.title("XGBoost Feature Importance")
plt.tight_layout()
plt.show()
# Out:
# Feature Importances:
# no2_neighbor_yesterday: 27.0
# NTL_mean: 10.0
# pop_sum_m: 6.0
# no2_yesterday: 3.0
# road_len: 0
# road_share: 0
# poi_count: 0
# poi_share: 0
# lu_industrial_area: 0
# lu_industrial_share: 0
# lu_commercial_area: 0
# lu_commercial_share: 0
# lu_residential_area: 0
# lu_residential_share: 0
# lu_retail_area: 0
# lu_retail_share: 0
# lu_farmland_area: 0
# lu_farmland_share: 0
# lu_farmyard_area: 0
# lu_farmyard_share: 0
# road_motorway_len: 0
# road_trunk_len: 0
# road_primary_len: 0
# road_secondary_len: 0
# road_tertiary_len: 0
# road_residential_len: 0
# fossil_pp_count: 0

# %% [markdown]
# ### Baghdad

# %%
import geopandas as gpd
import pandas as pd
from tqdm import tqdm
from datetime import timedelta, datetime
import os

# 假设文件按日期排序，文件名可解析为日期
mesh_bag = DATA_PATH / 'baghdad-mesh-data'
file_paths = sorted(mesh_bag.glob("*.gpkg"))  # 你的 730 个 GPKG 文件路径

all_data = []

for i, path in tqdm(enumerate(file_paths), total=len(file_paths)):
    date = datetime(2023, 1, 1) + timedelta(days=i)  # 修改起始日期为真实值
    gdf = gpd.read_file(path)
    gdf["date"] = date
    all_data.append(gdf)

full_bag_df = pd.concat(all_data, ignore_index=True)
# Out:
# 100%|██████████| 731/731 [01:01<00:00, 11.94it/s]
# C:\Users\87383\AppData\Local\Temp\ipykernel_30340\1749724562.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_bag_df = pd.concat(all_data, ignore_index=True)

# %%
## Yesterday NO2
full_bag_df.sort_values(["geom_id", "date"], inplace=True)
full_bag_df["no2_yesterday"] = full_bag_df.groupby("geom_id")["no2_mean"].shift(1)

# %%
import warnings
from libpysal.weights import KNN

# 假设 sample_gdf 是某一天的网格
sample_gdf = full_bag_df[full_bag_df['date'] == full_bag_df['date'].min()].reset_index(drop=True)

# 设置 K（邻居个数）
k_neighbors = 8  # 通常选择8邻域

# 构建 KNN 空间权重
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    w = KNN.from_dataframe(sample_gdf, k=k_neighbors)

# row-standardized weights（可选）
w.transform = 'r'

# 构建 geom_id -> 邻居 geom_id 的映射字典
geom_id_to_neighbors_bag = {}

# sample_gdf 的索引 i <=> geom_id 的映射
index_to_geom_id = dict(sample_gdf['geom_id'].items())

for i, neighbors in w.neighbors.items():
    geom_id = index_to_geom_id[i]
    neighbor_ids = [index_to_geom_id[j] for j in neighbors]
    geom_id_to_neighbors_bag[geom_id] = neighbor_ids

# %%
geom_id_to_neighbors_bag
# Out:
# {0: [1, 6, 5, 7, 2, 13, 8, 4],
#  1: [0, 2, 7, 6, 8, 14, 3, 5],
#  2: [1, 8, 3, 7, 9, 0, 15, 6],
#  3: [9, 2, 8, 16, 1, 7, 15, 14],
#  4: [5, 11, 12, 10, 6, 26, 13, 0],
#  5: [6, 4, 12, 0, 13, 11, 7, 27],
#  6: [7, 5, 13, 0, 14, 1, 12, 8],
#  7: [6, 8, 14, 1, 13, 0, 15, 2],
#  8: [7, 15, 2, 9, 14, 1, 16, 3],
#  9: [16, 3, 8, 2, 15, 31, 7, 14],
#  10: [25, 11, 4, 24, 26, 40, 12, 39],
#  11: [26, 12, 4, 10, 27, 5, 25, 13],
#  12: [13, 27, 11, 5, 28, 6, 4, 26],
#  13: [12, 14, 6, 28, 7, 29, 5, 27],
#  14: [13, 15, 7, 29, 28, 30, 8, 6],
#  15: [14, 8, 30, 16, 7, 29, 31, 9],
#  16: [9, 31, 15, 30, 8, 46, 3, 14],
#  17: [18, 32, 33, 19, 47, 48, 34, 49],
#  18: [17, 19, 33, 32, 34, 48, 20, 47],
#  19: [18, 34, 20, 33, 35, 17, 49, 21],
#  20: [21, 35, 19, 36, 34, 22, 50, 18],
#  21: [22, 36, 20, 37, 35, 23, 51, 19],
#  22: [21, 37, 23, 36, 38, 20, 24, 52],
#  23: [24, 38, 22, 39, 37, 21, 25, 53],
#  24: [39, 23, 25, 38, 40, 10, 22, 54],
#  25: [40, 10, 24, 26, 39, 41, 11, 23],
#  26: [41, 27, 11, 25, 42, 40, 12, 10],
#  27: [42, 28, 12, 26, 43, 41, 13, 11],
#  28: [29, 27, 13, 43, 42, 12, 44, 14],
#  29: [28, 30, 44, 14, 43, 15, 45, 13],
#  30: [29, 45, 15, 31, 14, 44, 46, 16],
#  31: [46, 16, 30, 45, 15, 61, 9, 29],
#  32: [33, 47, 17, 48, 18, 34, 62, 49],
#  33: [48, 32, 34, 18, 47, 49, 17, 19],
#  34: [49, 33, 19, 35, 48, 18, 50, 20],
#  35: [50, 36, 20, 34, 51, 21, 49, 19],
#  36: [37, 51, 35, 21, 52, 22, 50, 20],
#  37: [36, 22, 38, 52, 21, 51, 23, 53],
#  38: [39, 23, 37, 53, 24, 22, 54, 52],
#  39: [24, 38, 54, 40, 23, 53, 25, 55],
#  40: [25, 41, 39, 55, 24, 26, 56, 54],
#  41: [26, 42, 40, 56, 27, 25, 57, 55],
#  42: [27, 43, 41, 57, 28, 58, 26, 56],
#  993: [1066, 926, 994, 992, 1067, 927, 1065, 925],
#  994: [995, 1067, 927, 993, 928, 1068, 1066, 926],
#  995: [994, 928, 996, 1068, 927, 1067, 929, 1069],
#  996: [997, 929, 995, 1069, 930, 928, 1070, 1068],
#  997: [930, 996, 1070, 998, 929, 931, 1069, 1071],
#  998: [931, 999, 1071, 997, 932, 930, 1070, 1072],
#  999: [932, 1000, 998, 1072, 933, 931, 1073, 1071],
#  ...}

# %%
# full_df

# %%
def compute_neighbor_no2(row, df_dict):
    date = row["date"]
    geom_id = row["geom_id"]
    prev_date = date - timedelta(days=1)
    if prev_date not in df_dict:
        return None
    prev_day_df = df_dict[prev_date]
    neighbors = geom_id_to_neighbors.get(geom_id, [])
    values = prev_day_df[prev_day_df["geom_id"].isin(neighbors)]["no2_mean"]
    return values.mean() if not values.empty else None

# 按天切分数据用于快速访问
df_by_date = {d: gdf for d, gdf in full_bag_df.groupby("date")}
full_bag_df["no2_neighbor_yesterday"] = full_bag_df.apply(lambda row: compute_neighbor_no2(row, df_by_date), axis=1)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np

# 去除缺失值
clean_df = full_bag_df.dropna(subset=["no2_mean", "no2_yesterday", "no2_neighbor_yesterday"])

# 选特征
features = ["no2_yesterday", "no2_neighbor_yesterday"] + [
    col for col in full_bag_df.columns
    if col not in ["no2_mean", "geometry", "date", "geom_id", "no2_yesterday", "no2_neighbor_yesterday"]
]

X = clean_df[features].values
y = clean_df["no2_mean"].values.reshape(-1, 1)  # 目标需要2D给scaler

# 划分训练测试集（不打乱）
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 归一化
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# 只用训练数据fit，避免数据泄漏
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train).ravel()  # ravel转成1D，xgboost需要
y_test_scaled = scaler_y.transform(y_test).ravel()

# 创建 DMatrix，带特征名
dtrain = xgb.DMatrix(X_train_scaled, label=y_train_scaled, feature_names=features)
dtest = xgb.DMatrix(X_test_scaled, label=y_test_scaled, feature_names=features)

params = {
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "max_depth": 6,
    "eta": 0.1
}

evals = [(dtrain, "train"), (dtest, "eval")]
num_round = 100

evals_result = {}

bst = xgb.train(
    params, dtrain, num_round, evals,
    evals_result=evals_result,
    verbose_eval=True
)

# 预测，得到的是归一化后的预测值
y_pred_scaled = bst.predict(dtest)

# 反归一化回原始尺度
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()

print("Final RMSE (original scale):", mean_squared_error(y_test.ravel(), y_pred, squared=False))

# 画训练过程RMSE曲线（归一化指标）
plt.plot(evals_result['train']['rmse'], label='Train RMSE')
plt.plot(evals_result['eval']['rmse'], label='Eval RMSE')
plt.xlabel('Iteration')
plt.ylabel('RMSE (scaled)')
plt.title('XGBoost Training Progress')
plt.legend()
plt.show()

# 输出特征重要性
importance_dict = bst.get_score(importance_type='weight')
importances = [(feat, importance_dict.get(feat, 0)) for feat in features]
importances.sort(key=lambda x: x[1], reverse=True)

print("Feature Importances:")
for feat, score in importances:
    print(f"{feat}: {score}")

plt.figure(figsize=(10, 6))
plt.barh([i[0] for i in importances][::-1], [i[1] for i in importances][::-1])
plt.xlabel("Feature Importance (weight)")
plt.title("XGBoost Feature Importance")
plt.tight_layout()
plt.show()
